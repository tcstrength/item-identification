# %%
import pandas as pd
from unidecode import unidecode

# %%
file_path = "/Volumes/Cucumber/Projects/item-identification/local/Track Label - Refined.tsv"

# %%
df = pd.read_csv(file_path, sep="\t")

# %%
# Out:
#           Bar Code                                       Product Name  \
# 0    8935015513189       Đường Vàng Thiên Nhiên Biên Hòa Gold Túi 1kg
# 1    8935015510522            Đường Vàng Khoáng Chất Biên Hòa Gói 1KG
# 2    8934868186540  Sữa Tắm Lifebuoy Chiết Xuất Cica và Muối Hồng ...
# 3    8801051128178  Sữa Tắm ON: The Body Dưỡng Ẩm Hương Hoa Diên V...
# 4    8935030221359   Sữa Tắm ON: The Body Dưỡng Ẩm Hương Thư Giãn 1kg
# ..             ...                                                ...
# 127  8935049510857                          Nước Lọc Dasani Chai 1.5L
# 128  8934774000800                  Nước Khoáng Kiềm Vikoda Chai 1.5L
# 129  8935049501541                  Nước Ngọt CocaCola Plus Lon 320ML
# 130  8935049500445                          Nước Ngọt Fanta Chai 1.5L
# 131  4902102038720                  Nước Ngọt Fanta Nắp Vặn Lon 300ML
#
#      Task ID                                       Example File  Unnamed: 4  \
# ...
