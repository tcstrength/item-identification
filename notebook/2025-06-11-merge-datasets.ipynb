# %%
from hcmus.core import appconfig
# Out:
# 2025-06-11 13:25:59.902 | INFO     | hcmus.core.appconfig:<module>:7 - Load DotEnv: True

# %%
from loguru import logger
from hcmus.data import COCODatasetMerger
# Out:
# /Volumes/Cucumber/Projects/item-identification/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
split_weights = {
    'train': {'weight1': 1, 'weight2': 0.1},
    'val': {'weight1': 1, 'weight2': 0.0},
    'test': {'weight1': 1, 'weight2': 0.0}
}
merger = COCODatasetMerger(
    "/Volumes/Cucumber/Projects/datasets/hcmus-iid-2",
    "/Volumes/Cucumber/Projects/datasets/sku110k-zoom",
    "/Volumes/Cucumber/Projects/datasets/2025-06-11/sku110k-merged",
    split_weights
)

num_classes, categories = merger.merge_datasets()
logger.info(f"Dataset merged successfully!")
logger.info(f"Number of classes: {num_classes}")
logger.info(f"Categories: {[cat['name'] for cat in categories]}")
# Out:
# 2025-06-11 11:32:18.351 | INFO     | hcmus.data._coco_merger:__init__:37 - Splits to merge: dict_keys(['train', 'val', 'test'])
# 2025-06-11 11:32:18.352 | INFO     | hcmus.data._coco_merger:__init__:38 - Split weights: {'train': {'weight1': 1, 'weight2': 0.1}, 'val': {'weight1': 1, 'weight2': 0.0}, 'test': {'weight1': 1, 'weight2': 0.0}}

# %% [markdown]
# ### Keep SKU110k for Train, IID for Val + Test, treat `object` as label

# %%
split_weights = {
    'train': {'weight1': 0, 'weight2': 0.1},
    'val': {'weight1': 1, 'weight2': 0.0},
    'test': {'weight1': 1, 'weight2': 0.0}
}
merger = COCODatasetMerger(
    "/Volumes/Cucumber/Projects/datasets/hcmus-iid-object",
    "/Volumes/Cucumber/Projects/datasets/sku110k-zoom",
    "/Volumes/Cucumber/Projects/datasets/2025-06-11/sku110k-only",
    split_weights
)

num_classes, categories = merger.merge_datasets()
logger.info(f"Dataset merged successfully!")
logger.info(f"Number of classes: {num_classes}")
logger.info(f"Categories: {[cat['name'] for cat in categories]}")
# Out:
# 2025-06-11 13:29:04.334 | INFO     | hcmus.data._coco_merger:__init__:37 - Splits to merge: dict_keys(['train', 'val', 'test'])
# 2025-06-11 13:29:04.335 | INFO     | hcmus.data._coco_merger:__init__:38 - Split weights: {'train': {'weight1': 0, 'weight2': 0.1}, 'val': {'weight1': 1, 'weight2': 0.0}, 'test': {'weight1': 1, 'weight2': 0.0}}
# 2025-06-11 13:29:04.336 | INFO     | hcmus.data._coco_merger:merge_datasets:47 - Starting dataset merging...
# 2025-06-11 13:29:04.336 | INFO     | hcmus.data._coco_merger:_analyze_categories:69 - Analyzing categories from both datasets...
# 2025-06-11 13:29:05.707 | INFO     | hcmus.data._coco_merger:_analyze_categories:93 - Found 1 unique categories
# 2025-06-11 13:29:05.708 | INFO     | hcmus.data._coco_merger:_analyze_categories:94 - Total classes (including background): 2
# 2025-06-11 13:29:05.753 | INFO     | hcmus.data._coco_merger:_merge_split:114 - Merging train split...
# 2025-06-11 13:29:05.754 | INFO     | hcmus.data._coco_merger:_merge_split:120 - Using weights for train: dataset1=0, dataset2=0.1
# 2025-06-11 13:29:06.873 | INFO     | hcmus.data._coco_merger:_merge_split:163 - Dataset 1 images: 3071 -> 0 (weight: 0)
# 2025-06-11 13:29:06.874 | INFO     | hcmus.data._coco_merger:_merge_split:164 - Dataset 2 images: 8155 -> 815 (weight: 0.1)
# 2025-06-11 13:29:08.315 | INFO     | hcmus.data._coco_merger:_merge_split:243 - train split merged: 815 images, 43924 annotations
# 2025-06-11 13:29:08.350 | INFO     | hcmus.data._coco_merger:_merge_split:114 - Merging val split...
# 2025-06-11 13:29:08.351 | INFO     | hcmus.data._coco_merger:_merge_split:120 - Using weights for val: dataset1=1, dataset2=0.0
# 2025-06-11 13:29:08.551 | INFO     | hcmus.data._coco_merger:_merge_split:163 - Dataset 1 images: 30 -> 30 (weight: 1)
# 2025-06-11 13:29:08.551 | INFO     | hcmus.data._coco_merger:_merge_split:164 - Dataset 2 images: 588 -> 0 (weight: 0.0)
# 2025-06-11 13:29:08.581 | INFO     | hcmus.data._coco_merger:_merge_split:243 - val split merged: 30 images, 611 annotations
# 2025-06-11 13:29:08.591 | INFO     | hcmus.data._coco_merger:_merge_split:114 - Merging test split...
# 2025-06-11 13:29:08.591 | INFO     | hcmus.data._coco_merger:_merge_split:120 - Using weights for test: dataset1=1, dataset2=0.0
# 2025-06-11 13:29:09.625 | INFO     | hcmus.data._coco_merger:_merge_split:163 - Dataset 1 images: 346 -> 346 (weight: 1)
# 2025-06-11 13:29:09.625 | INFO     | hcmus.data._coco_merger:_merge_split:164 - Dataset 2 images: 2936 -> 0 (weight: 0.0)
# 2025-06-11 13:29:10.028 | INFO     | hcmus.data._coco_merger:_merge_split:243 - test split merged: 346 images, 13962 annotations
# 2025-06-11 13:29:10.056 | INFO     | hcmus.data._coco_merger:merge_datasets:60 - Dataset merging completed!
# 2025-06-11 13:29:10.057 | INFO     | hcmus.data._coco_merger:merge_datasets:61 - Processed splits: dict_keys(['train', 'val', 'test'])
# 2025-06-11 13:29:10.057 | INFO     | hcmus.data._coco_merger:merge_datasets:62 - Total number of classes: 2
# 2025-06-11 13:29:10.058 | INFO     | hcmus.data._coco_merger:merge_datasets:63 - Categories: ['object']
# 2025-06-11 13:29:10.058 | INFO     | __main__:<module>:14 - Dataset merged successfully!
# 2025-06-11 13:29:10.058 | INFO     | __main__:<module>:15 - Number of classes: 2
# 2025-06-11 13:29:10.059 | INFO     | __main__:<module>:16 - Categories: ['object']

# %%
import json
from hcmus.utils.viz_utils import draw_boxes
from PIL import Image, ImageOps
from hcmus.utils import viz_utils
dataset_dir = "/Volumes/Cucumber/Projects/datasets/2025-06-11/sku110k-only"
split_name = "val"
annotations_path = f"{dataset_dir}/{split_name}/annotations_{split_name}.json"
images_path = f"{dataset_dir}/{split_name}/images"
annotations = json.load(open(annotations_path))

# %%
a
# Out:
# {'id': 611,
#  'image_id': 30,
#  'category_id': 1,
#  'bbox': [191.25551544324105,
#   468.5920577617328,
#   68.03048535900524,
#   48.37545126353791],
#  'area': 3291.005428919387,
#  'iscrowd': 0}

# %%
idx = 4
image_idx = annotations.get("images")[idx]
image_path = images_path + "/" + image_idx.get("file_name")
image = Image.open(image_path)
image = ImageOps.exif_transpose(image)
boxes = []
labels = []
for a in annotations.get("annotations"):
    if a.get("image_id") == image_idx.get("id"):
        bbox = a.get("bbox")
        bbox[2] = bbox[0] + bbox[2]
        bbox[3] = bbox[1] + bbox[3]
        boxes.append(bbox)
        labels.append(str(a.get("category_id")))
viz_utils.draw_boxes(image, boxes)
