# %%
import requests
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image
from hcmus.models.identification_model import IdentificationModel
from hcmus.utils import viz_utils

# %%
image = Image.open("../../../dataset/20250224_122816.jpg")

# %%
model = IdentificationModel()
# Out:
# /Users/tccuong1404/Library/Caches/pypoetry/virtualenvs/item-identification-dwQqSUZL-py3.12/lib/python3.12/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /Users/tccuong1404/Library/Caches/pypoetry/virtualenvs/item-identification-dwQqSUZL-py3.12/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=FasterRCNN_ResNet50_FPN_Weights.COCO_V1`. You can also use `weights=FasterRCNN_ResNet50_FPN_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
tensor = model.transform(image)
result = model.predict(tensor)

# %%
viz_utils.draw_boxes(image, result)
